# %%
import pandas as pd

# %%
test = pd.read_csv('ECG5000_TEST.tsv')  
train = pd.read_csv('ECG5000_TRAIN.csv')

# %%
print(train.shape)
print(test.head(1))
# Out:
# (499, 141)
# ...

# %%
test
# Out:
#      1\t3.6908442\t0.71141435\t-2.1140915\t-4.1410068\t-4.5744716\t-3.4319085\t-1.9507914\t-1.1070667\t-0.63232248\t0.33457718\t0.87883579\t0.83106672\t0.83246584\t0.79099271\t0.73318448\t0.67531414\t0.76075122\t0.64545074\t0.64472425\t0.59314006\t0.60070077\t0.4967947\t0.40954629\t0.33081901\t0.15958058\t0.20091363\t0.10775284\t-0.039164736\t-0.096833474\t-0.17062963\t-0.2969516\t-0.38126935\t-0.36309706\t-0.5013618\t-0.67307625\t-0.55188068\t-0.65094102\t-0.54260816\t-0.66110174\t-0.58118387\t-0.45428738\t-0.45106516\t-0.29907368\t-0.21448719\t-0.076921402\t0.10233773\t0.20839504\t0.15054113\t0.21366603\t0.24493933\t0.30699451\t0.33835116\t0.34609696\t0.41369076\t0.44100555\t0.39159341\t0.41750854\t0.30276646\t0.38036357\t0.28972908\t0.37412731\t0.39876561\t0.36499806\t0.63122707\t0.50918961\t0.46911811\t0.61013159\t0.59380291\t0.56851494\t0.6185489\t0.75104048\t0.49345872\t0.53952164\t0.64126341\t0.60935203\t0.59405769\t0.40790413\t0.42761301\t0.43085571\t0.41528731\t0.31350561\t0
# ...

# %%
train
# Out:
#      1  -0.11252183  -2.8272037999999995  -3.7738968999999996  -4.3497511  \
# 0    1    -1.100878            -3.996840            -4.285843   -4.506579
# 1    1    -0.567088            -2.593450            -3.874230   -4.584095
# 2    1     0.490473            -1.914407            -3.616364   -4.318823
# 3    1     0.800232            -0.874252            -2.384761   -3.973292
# 4    1    -1.507674            -3.574550            -4.478011   -4.408275
# ..  ..          ...                  ...                  ...         ...
# 494  4    -0.478577            -1.779959            -2.398159   -3.170112
# 495  4    -1.325210            -2.480992            -2.965356   -3.342392
# 496  4    -0.021964            -0.912434            -1.903353   -2.662829
# 497  5     0.288011            -1.098020            -2.500250   -3.598599
# 498  5    -1.133674            -2.702941            -3.120979   -3.558669
#
#      -4.376041000000001  -3.4749863  -2.1814082000000004  -1.8182865000000001  \
# ...
