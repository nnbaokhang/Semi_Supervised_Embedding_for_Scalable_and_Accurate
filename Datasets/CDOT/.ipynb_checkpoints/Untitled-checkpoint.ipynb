# %%
import pandas as pd
import numpy as np
import csv
from ast import literal_eval
from sklearn.model_selection import train_test_split
X = pd.read_csv('Time_Series_For_Clustering_El_Paso_with_Weather_data.csv')
del(X['Bridge_id'])
X["total"] = (X["time_0"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_1"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_2"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_3"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_4"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_5"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_6"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_7"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_8"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_9"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_10"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_11"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_12"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_13"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_14"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_15"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_16"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_17"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_18"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_19"].apply(lambda x: x.replace('[','').replace(']',''))) + (X["time_20"].apply(lambda x: x.replace('[','').replace(']',''))) +  (X["time_21"].apply(lambda x: x.replace('[','').replace(']',''))) 
del(X['time_0']);del(X['time_1']);del(X['time_2']);del(X['time_3']);del(X['time_4']);del(X['time_5']);del(X['time_6']);del(X['time_7']);del(X['time_8']);del(X['time_9']);del(X['time_10']);del(X['time_11']);del(X['time_12']);del(X['time_13']);del(X['time_14']);del(X['time_15']);del(X['time_16']);del(X['time_17']);del(X['time_18']);del(X['time_19']);del(X['time_20']);del(X['time_21'])
#x[~x.index.isin([0, 3, 4])]
#print(X)
X["total"] = X["total"].astype('str')
X["total"] = X["total"].str.replace(' ', '')
#for index, row in X.iterrows():
#    print(row['total'][1:-1])
 
X.to_csv('CDOT_v2.csv')
X= pd.read_csv('CDOT_v2.csv',skiprows=1)

X_train, X_test = train_test_split(X,test_size=0.4, random_state=42)

# %%
for index, row in X.iterrows():
    print(row)
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 507 to 312
# Data columns (total 2 columns):
# ...

# %%
X_train
# Out:
#        0  \
# 168  169
# 188  189
# 275  276
# 392  393
# 487  488
# ..   ...
# 71    72
# 106  107
# 270  271
# 435  436
# 102  103
#
# ...

# %%
X_train.to_csv('CDOT_TRAIN.csv',quoting=csv.QUOTE_NONE,escapechar='\\', quotechar='')
X_test.to_csv('CDOT_TEST.csv',quoting=csv.QUOTE_NONE,escapechar='\\', quotechar='')

'''
X_train = pd.read_csv('CDOT_TRAIN.csv',skiprows=1)
X_test =  pd.read_csv('CDOT_TEST.csv',skiprows=1)
X_train = X_train.replace('\\', '')
X_test = X_test.replace('\\', '')
X_train.to_csv('CDOT_TRAIN.csv')
X_test.to_csv('CDOT_TEST.csv')
'''

# %%
test = X_train.head(1)
